# %%
birds.plot(kind='scatter',x='MaxLength',y='Order',figsize=(12,8))

plt.title = ('Maxlenght per order')
plt.ylabel = ('order')
plt.title = ('Maxlenght')

plt.show()

# %%
birds['MaxBodyMass'].plot(kind='hist',bins = 10, figsize=(12,12))
plt.show()

# %%
birds['MaxBodyMass'].plot(kind='hist',bins=30,figsize=(12,12))
plt.show()

# %%
filtered_birds = birds[(birds['MaxBodyMass'] > 1) & (birds['MaxBodyMass'] < 60)]
filtered_birds['MaxBodyMass'].plot(kind='hist',bins=40,figsize=(12,12))
plt.show()

# %%
filteredBirds = birds[(birds['MaxBodyMass'] > 1) & (birds['MaxBodyMass'] < 60)]      
filteredBirds['MaxBodyMass'].plot(kind = 'hist',bins = 40,figsize = (12,12))
plt.show()

# %%
x = filtered_birds['MaxBodyMass']
y = filtered_birds['MaxLength']

fig, ax = plt.subplots(tight_layout = True)
hist = ax.hist2d(x,y)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.kdeplot(filtered_birds['MinWingspan'])
plt.show()

# %%
sns.kdeplot(filtered_birds['MaxBodyMass'])
plt.show()

# %%
sns.kdeplot(filtered_birds['MaxLength'])
plt.show()

# %%
sns.kdeplot(filtered_birds['MaxBodyMass'] , bw_adjust= .2)
plt.show()

# %%
sns.kdeplot(filtered_birds['MinBodyMass'], bw_adjust= .2)
plt.show()

# %%
sns.kdeplot(filtered_birds['MinLength'], bw_adjust= .2)
plt.show()
